# %%
# License: BSD
# Author: Sasank Chilamkurthy

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
from PIL import Image
from tempfile import TemporaryDirectory

cudnn.benchmark = True
plt.ion()   # interactive mode

# %%
# حذف مجلدات الـ checkpoints المخفية التي تسبب المشكلة
# !rm -rf hymenoptera_data/train/.ipynb_checkpoints
# !rm -rf hymenoptera_data/val/.ipynb_checkpoints
# !rm -rf .ipynb_checkpoints

# %%
# Data augmentation and normalization for training
# Just normalization for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_dir = 'hymenoptera_data'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

# We want to be able to train our model on an `accelerator <https://pytorch.org/docs/stable/torch.html#accelerators>`__
# such as CUDA, MPS, MTIA, or XPU. If the current accelerator is available, we will use it. Otherwise, we use the CPU.

device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %%
def imshow(inp, title=None):
    """Display image for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    # Create a temporary directory to save training checkpoints
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0

        for epoch in range(num_epochs):
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)

            # Each epoch has a training and validation phase
            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()  # Set model to training mode
                else:
                    model.eval()   # Set model to evaluate mode

                running_loss = 0.0
                running_corrects = 0

                # Iterate over data.
                for inputs, labels in dataloaders[phase]:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)

                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    running_loss += loss.item() * inputs.size(0)
                    running_corrects += torch.sum(preds == labels.data)
                if phase == 'train':
                    scheduler.step()

                epoch_loss = running_loss / dataset_sizes[phase]
                epoch_acc = running_corrects.double() / dataset_sizes[phase]

                print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

                # deep copy the model
                if phase == 'val' and epoch_acc > best_acc:
                    best_acc = epoch_acc
                    torch.save(model.state_dict(), best_model_params_path)

            print()

        time_elapsed = time.time() - since
        print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')

        # load best model weights
        model.load_state_dict(torch.load(best_model_params_path, weights_only=True))
    return model

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {class_names[preds[j]]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
model_ft = models.resnet18(weights='IMAGENET1K_V1')
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to ``nn.Linear(num_ftrs, len(class_names))``.
model_ft.fc = nn.Linear(num_ftrs, 2)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 82.3MB/s]

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.5716 Acc: 0.6926
# val Loss: 0.4512 Acc: 0.8039
#
# Epoch 1/24
# ----------
# train Loss: 0.8534 Acc: 0.7377
# val Loss: 0.5154 Acc: 0.8562
#
# Epoch 2/24
# ----------
# train Loss: 0.4933 Acc: 0.8156
# val Loss: 0.3321 Acc: 0.8758
#
# Epoch 3/24
# ----------
# train Loss: 0.4238 Acc: 0.8115
# val Loss: 0.5061 Acc: 0.8039
#
# Epoch 4/24
# ----------
# train Loss: 0.6683 Acc: 0.7500
# val Loss: 0.3299 Acc: 0.8562
#
# Epoch 5/24
# ----------
# train Loss: 0.4077 Acc: 0.8402
# val Loss: 0.2032 Acc: 0.9216
#
# Epoch 6/24
# ----------
# train Loss: 0.4943 Acc: 0.8197
# val Loss: 0.3290 Acc: 0.8758
#
# Epoch 7/24
# ----------
# train Loss: 0.3314 Acc: 0.8770
# val Loss: 0.2280 Acc: 0.9020
#
# Epoch 8/24
# ----------
# train Loss: 0.2326 Acc: 0.9016
# val Loss: 0.2041 Acc: 0.9020
#
# Epoch 9/24
# ----------
# train Loss: 0.3729 Acc: 0.8443
# val Loss: 0.2058 Acc: 0.9216
#
# Epoch 10/24
# ----------
# train Loss: 0.2295 Acc: 0.9016
# val Loss: 0.1987 Acc: 0.9281
#
# Epoch 11/24
# ----------
# train Loss: 0.2749 Acc: 0.8934
# val Loss: 0.1972 Acc: 0.9020
#
# Epoch 12/24
# ----------
# train Loss: 0.2968 Acc: 0.8770
# val Loss: 0.1879 Acc: 0.9150
#
# Epoch 13/24
# ----------
# train Loss: 0.3102 Acc: 0.8402
# val Loss: 0.1962 Acc: 0.9150
#
# Epoch 14/24
# ----------
# train Loss: 0.3099 Acc: 0.8975
# val Loss: 0.2001 Acc: 0.9085
#
# Epoch 15/24
# ----------
# train Loss: 0.2543 Acc: 0.8770
# val Loss: 0.1829 Acc: 0.9085
#
# Epoch 16/24
# ----------
# train Loss: 0.3504 Acc: 0.8525
# val Loss: 0.2227 Acc: 0.9150
#
# Epoch 17/24
# ----------
# train Loss: 0.3094 Acc: 0.8648
# val Loss: 0.1971 Acc: 0.9020
#
# Epoch 18/24
# ----------
# train Loss: 0.2514 Acc: 0.8770
# val Loss: 0.1697 Acc: 0.9150
#
# Epoch 19/24
# ----------
# train Loss: 0.2527 Acc: 0.8689
# val Loss: 0.1753 Acc: 0.9216
#
# Epoch 20/24
# ----------
# train Loss: 0.2954 Acc: 0.8893
# val Loss: 0.1698 Acc: 0.9216
#
# Epoch 21/24
# ----------
# train Loss: 0.3040 Acc: 0.8648
# val Loss: 0.1890 Acc: 0.9085
#
# Epoch 22/24
# ----------
# train Loss: 0.3037 Acc: 0.8689
# val Loss: 0.1934 Acc: 0.9020
#
# Epoch 23/24
# ----------
# train Loss: 0.3124 Acc: 0.8934
# val Loss: 0.1711 Acc: 0.9085
#
# Epoch 24/24
# ----------
# train Loss: 0.2392 Acc: 0.8975
# val Loss: 0.1766 Acc: 0.9020
#
# Training complete in 1m 20s
# Best val Acc: 0.928105

# %%
model_conv = torchvision.models.resnet18(weights='IMAGENET1K_V1')
for param in model_conv.parameters():
    param.requires_grad = False

# Parameters of newly constructed modules have requires_grad=True by default
num_ftrs = model_conv.fc.in_features
model_conv.fc = nn.Linear(num_ftrs, 2)

model_conv = model_conv.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that only parameters of final layer are being optimized as
# opposed to before.
optimizer_conv = optim.SGD(model_conv.fc.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)

# %%
model_conv = train_model(model_conv, criterion, optimizer_conv,
                         exp_lr_scheduler, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.7058 Acc: 0.6311
# val Loss: 0.1982 Acc: 0.9412
#
# Epoch 1/24
# ----------
# train Loss: 0.3863 Acc: 0.7992
# val Loss: 0.2303 Acc: 0.9216
#
# Epoch 2/24
# ----------
# train Loss: 0.5258 Acc: 0.7746
# val Loss: 0.1596 Acc: 0.9477
#
# Epoch 3/24
# ----------
# train Loss: 0.4478 Acc: 0.8361
# val Loss: 0.1652 Acc: 0.9477
#
# Epoch 4/24
# ----------
# train Loss: 0.5564 Acc: 0.7705
# val Loss: 0.3605 Acc: 0.8627
#
# Epoch 5/24
# ----------
# train Loss: 0.4509 Acc: 0.7951
# val Loss: 0.2161 Acc: 0.9542
#
# Epoch 6/24
# ----------
# train Loss: 0.4806 Acc: 0.8320
# val Loss: 0.2166 Acc: 0.9346
#
# Epoch 7/24
# ----------
# train Loss: 0.3278 Acc: 0.8607
# val Loss: 0.1807 Acc: 0.9412
#
# Epoch 8/24
# ----------
# train Loss: 0.3505 Acc: 0.8525
# val Loss: 0.1828 Acc: 0.9346
#
# Epoch 9/24
# ----------
# train Loss: 0.3135 Acc: 0.8607
# val Loss: 0.2128 Acc: 0.9281
#
# Epoch 10/24
# ----------
# train Loss: 0.3172 Acc: 0.8525
# val Loss: 0.1853 Acc: 0.9412
#
# Epoch 11/24
# ----------
# train Loss: 0.2955 Acc: 0.8811
# val Loss: 0.1968 Acc: 0.9346
#
# Epoch 12/24
# ----------
# train Loss: 0.2885 Acc: 0.8443
# val Loss: 0.2069 Acc: 0.9346
#
# Epoch 13/24
# ----------
# train Loss: 0.2888 Acc: 0.8730
# val Loss: 0.1754 Acc: 0.9412
#
# Epoch 14/24
# ----------
# train Loss: 0.2908 Acc: 0.8770
# val Loss: 0.1797 Acc: 0.9412
#
# Epoch 15/24
# ----------
# train Loss: 0.2668 Acc: 0.8689
# val Loss: 0.1792 Acc: 0.9412
#
# Epoch 16/24
# ----------
# train Loss: 0.3041 Acc: 0.8852
# val Loss: 0.2245 Acc: 0.9216
#
# Epoch 17/24
# ----------
# train Loss: 0.2596 Acc: 0.8975
# val Loss: 0.1821 Acc: 0.9346
#
# Epoch 18/24
# ----------
# train Loss: 0.3686 Acc: 0.8361
# val Loss: 0.1876 Acc: 0.9477
#
# Epoch 19/24
# ----------
# train Loss: 0.4097 Acc: 0.8525
# val Loss: 0.1912 Acc: 0.9346
#
# Epoch 20/24
# ----------
# train Loss: 0.3504 Acc: 0.8443
# val Loss: 0.1952 Acc: 0.9346
#
# Epoch 21/24
# ----------
# train Loss: 0.3316 Acc: 0.8566
# val Loss: 0.1830 Acc: 0.9346
#
# Epoch 22/24
# ----------
# train Loss: 0.3086 Acc: 0.8648
# val Loss: 0.1814 Acc: 0.9412
#
# Epoch 23/24
# ----------
# train Loss: 0.3690 Acc: 0.8525
# val Loss: 0.2185 Acc: 0.9216
#
# Epoch 24/24
# ----------
# train Loss: 0.3074 Acc: 0.8770
# val Loss: 0.1903 Acc: 0.9281
#
# Training complete in 1m 10s
# Best val Acc: 0.954248

# %%
visualize_model(model_conv)

plt.ioff()
plt.show()

# %%
def visualize_model_predictions(model,img_path):
    was_training = model.training
    model.eval()

    img = Image.open(img_path)
    img = data_transforms['val'](img)
    img = img.unsqueeze(0)
    img = img.to(device)

    with torch.no_grad():
        outputs = model(img)
        _, preds = torch.max(outputs, 1)

        ax = plt.subplot(2,2,1)
        ax.axis('off')
        ax.set_title(f'Predicted: {class_names[preds[0]]}')
        imshow(img.cpu().data[0])

        model.train(mode=was_training)

# %%
visualize_model_predictions(
    model_conv,
    img_path='hymenoptera_data/val/bees/72100438_73de9f17af.jpg'
)

plt.ioff()
plt.show()

# %%
# 1. تحميل نموذج ResNet18 المدرب مسبقاً
model_ft = models.resnet18(weights='IMAGENET1K_V1')

# 2. تغيير الطبقة الأخيرة لتناسب عدد الأصناف عندنا (2: نمل ونحل)
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, 2) # رقم 2 هو عدد الكلاسات (ants, bees)

# 3. نقل النموذج إلى الـ GPU لسرعة التدريب
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_ft = model_ft.to(device)

# 4. تحديد دالة حساب الخطأ (Loss Function)
criterion = nn.CrossEntropyLoss()

# 5. تحديد المحسن (Optimizer) - وهنا يكمن السر!
# لاحظ أننا مررنا (model_ft.parameters) وهذا يعني أننا سنحدث أوزان الشبكة كاملة
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# 6. تحديد مجدول معدل التعلم (يقلل السرعة كل 7 دورات)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# 7. بدء التدريب الفعلي
print("Start Fine-Tuning Training...")
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=25)
# Out:
# Start Fine-Tuning Training...
# Epoch 0/24
# ----------
# train Loss: 0.6644 Acc: 0.6844
# val Loss: 0.2195 Acc: 0.9281
#
# Epoch 1/24
# ----------
# train Loss: 0.6503 Acc: 0.7049
# val Loss: 0.3849 Acc: 0.8301
#
# Epoch 2/24
# ----------
# train Loss: 0.5879 Acc: 0.7869
# val Loss: 0.3075 Acc: 0.8889
#
# Epoch 3/24
# ----------
# train Loss: 0.4672 Acc: 0.8033
# val Loss: 0.4702 Acc: 0.8301
#
# Epoch 4/24
# ----------
# train Loss: 0.5249 Acc: 0.8156
# val Loss: 0.3555 Acc: 0.8627
#
# Epoch 5/24
# ----------
# train Loss: 0.4796 Acc: 0.7869
# val Loss: 0.3563 Acc: 0.8824
#
# Epoch 6/24
# ----------
# train Loss: 0.6728 Acc: 0.7459
# val Loss: 0.4014 Acc: 0.8758
#
# Epoch 7/24
# ----------
# train Loss: 0.4515 Acc: 0.8197
# val Loss: 0.3453 Acc: 0.8693
#
# Epoch 8/24
# ----------
# train Loss: 0.3379 Acc: 0.8566
# val Loss: 0.2662 Acc: 0.9150
#
# Epoch 9/24
# ----------
# train Loss: 0.3394 Acc: 0.8525
# val Loss: 0.2746 Acc: 0.9020
#
# Epoch 10/24
# ----------
# train Loss: 0.3684 Acc: 0.8443
# val Loss: 0.2564 Acc: 0.9150
#
# Epoch 11/24
# ----------
# train Loss: 0.3002 Acc: 0.8893
# val Loss: 0.2291 Acc: 0.9281
#
# Epoch 12/24
# ----------
# train Loss: 0.2727 Acc: 0.8811
# val Loss: 0.2368 Acc: 0.9150
#
# Epoch 13/24
# ----------
# train Loss: 0.3599 Acc: 0.8402
# val Loss: 0.2465 Acc: 0.9085
#
# Epoch 14/24
# ----------
# train Loss: 0.2392 Acc: 0.8934
# val Loss: 0.2443 Acc: 0.9216
#
# Epoch 15/24
# ----------
# train Loss: 0.2379 Acc: 0.8893
# val Loss: 0.2455 Acc: 0.9020
#
# Epoch 16/24
# ----------
# train Loss: 0.2679 Acc: 0.8893
# val Loss: 0.2417 Acc: 0.9346
#
# Epoch 17/24
# ----------
# train Loss: 0.2871 Acc: 0.8566
# val Loss: 0.2413 Acc: 0.9216
#
# Epoch 18/24
# ----------
# train Loss: 0.2701 Acc: 0.8648
# val Loss: 0.2387 Acc: 0.9216
#
# Epoch 19/24
# ----------
# train Loss: 0.2731 Acc: 0.8893
# val Loss: 0.2331 Acc: 0.9281
#
# Epoch 20/24
# ----------
# train Loss: 0.2585 Acc: 0.8893
# val Loss: 0.2348 Acc: 0.9281
#
# Epoch 21/24
# ----------
# train Loss: 0.2482 Acc: 0.8893
# val Loss: 0.2328 Acc: 0.9281
#
# Epoch 22/24
# ----------
# train Loss: 0.2767 Acc: 0.8770
# val Loss: 0.2294 Acc: 0.9216
#
# Epoch 23/24
# ----------
# train Loss: 0.3042 Acc: 0.8361
# val Loss: 0.2578 Acc: 0.9020
#
# Epoch 24/24
# ----------
# train Loss: 0.3233 Acc: 0.8443
# val Loss: 0.2576 Acc: 0.9085
#
# Training complete in 1m 19s
# Best val Acc: 0.934641

# %%
# حفظ الأوزان المدربة في ملف
torch.save(model_ft.state_dict(), 'ft_ant_bee_model.pth')
print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
visualize_model(model_ft)
